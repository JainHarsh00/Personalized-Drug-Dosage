# %% [markdown]
# # MVP 3 Adding Stochasticity

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class PatientEnvGymStochastic(gym.Env):
    def __init__(self):
        super().__init__()
        print("Stochastic Patient Environment created!")

        # --- Pharmacokinetics ---
        self.base_decay_rate = 0.1  # The average decay rate
        self.decay_noise_level = 0.02 # The amount of randomness

        # Therapeutic Window
        self.target_min = 5.0
        self.target_max = 15.0
        
        # Action and Observation Spaces 
        self.action_space = spaces.Box(low=0.0, high=20.0, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=0.0, high=100.0, shape=(1,), dtype=np.float32)

        # Episode Tracking 
        self.max_steps = 100

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_concentration = 0.0
        self.current_step = 0
        return np.array([self.current_concentration]).astype(np.float32), {}

    def step(self, action):
        dosage_administered = np.asarray(action).item()
        
        # We sample from a normal distribution (a bell curve) to get some noise
        random_noise = np.random.normal(loc=0.0, scale=self.decay_noise_level)
        
        # The actual decay rate for this step is the base rate + noise
        current_decay_rate = self.base_decay_rate + random_noise
        
        # A safety check to ensure the decay rate doesn't become negative or too low
        current_decay_rate = max(0.01, current_decay_rate)
        
        # Update concentration using the new, noisy decay rate
        drug_cleared = self.current_concentration * current_decay_rate
        self.current_concentration += dosage_administered - drug_cleared
        self.current_concentration = max(0, self.current_concentration)
        
        # Reward and episode end logic remain exactly the same
        if self.target_min <= self.current_concentration <= self.target_max:
            reward = 1
        else:
            reward = -1
        
        self.current_step += 1
        
        terminated = False 
        truncated = self.current_step >= self.max_steps
        
        next_state = np.array([self.current_concentration]).astype(np.float32)
        
        return next_state, reward, terminated, truncated, {}

# %%
from stable_baselines3 import PPO

env = PatientEnvGymStochastic()

model = PPO('MlpPolicy', env, verbose=1)

model.learn(total_timesteps=150000)

print("Training finished!")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Stochastic Patient Environment created!
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -71.6    |
# | time/              |          |
# |    fps             | 2263     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -52.1       |
# | time/                   |             |
# |    fps                  | 1497        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008483817 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0149      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1.01        |
# |    value_loss           | 55.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -31.3       |
# | time/                   |             |
# |    fps                  | 1358        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011223598 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.0455     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 1.01        |
# |    value_loss           | 63.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -10.8       |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016110756 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0057      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 1.02        |
# |    value_loss           | 66.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 6.9         |
# | time/                   |             |
# |    fps                  | 1251        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010696991 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.047       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 1.02        |
# |    value_loss           | 79.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 37.3         |
# | time/                   |              |
# |    fps                  | 1209         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0071356473 |
# |    clip_fraction        | 0.0814       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0518       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.4         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 1.02         |
# |    value_loss           | 97.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 61.1         |
# | time/                   |              |
# |    fps                  | 1187         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0024945333 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.063        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00286     |
# |    std                  | 1.02         |
# |    value_loss           | 103          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 75.1        |
# | time/                   |             |
# |    fps                  | 1176        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004820622 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0671      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0041     |
# |    std                  | 1.02        |
# |    value_loss           | 86.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005376662 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00601    |
# |    std                  | 1.01        |
# |    value_loss           | 72          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 87.3         |
# | time/                   |              |
# |    fps                  | 1141         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0025885196 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0763       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00271     |
# |    std                  | 1.01         |
# |    value_loss           | 60.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 89.2        |
# | time/                   |             |
# |    fps                  | 1139        |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004719263 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0527      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.993       |
# |    value_loss           | 49.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 90.8         |
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 12           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0064107873 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0625       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.76         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 0.999        |
# |    value_loss           | 37.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 92.9         |
# | time/                   |              |
# |    fps                  | 1123         |
# |    iterations           | 13           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0032437262 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0409       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00176     |
# |    std                  | 1            |
# |    value_loss           | 28.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 93.8        |
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 14          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007867284 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0407      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000922   |
# |    std                  | 1.01        |
# |    value_loss           | 20.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 94.6        |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 15          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007373173 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0413      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00136    |
# |    std                  | 1.02        |
# |    value_loss           | 13.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 95.4         |
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 16           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0048271185 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0488       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000107    |
# |    std                  | 1.01         |
# |    value_loss           | 9.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 96          |
# | time/                   |             |
# |    fps                  | 1124        |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003848208 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0204      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.923       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000701   |
# |    std                  | 1.01        |
# |    value_loss           | 6.48        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 96.5         |
# | time/                   |              |
# |    fps                  | 1121         |
# |    iterations           | 18           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0030250733 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0369       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.681        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000502    |
# |    std                  | 1.02         |
# |    value_loss           | 4.29         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.1        |
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 19          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005405294 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0518      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.41        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000352   |
# |    std                  | 1.01        |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.4        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 20          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004530697 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0484      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.37        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000539    |
# |    std                  | 1           |
# |    value_loss           | 1.86        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.6         |
# | time/                   |              |
# |    fps                  | 1114         |
# |    iterations           | 21           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0050773816 |
# |    clip_fraction        | 0.0914       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0342       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.295        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00268     |
# |    std                  | 0.985        |
# |    value_loss           | 1.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.7         |
# | time/                   |              |
# |    fps                  | 1115         |
# |    iterations           | 22           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0063564633 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0801       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.148        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000506    |
# |    std                  | 0.981        |
# |    value_loss           | 0.841        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.9         |
# | time/                   |              |
# |    fps                  | 1116         |
# |    iterations           | 23           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0048281895 |
# |    clip_fraction        | 0.062        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0861       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.108        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000997     |
# |    std                  | 0.982        |
# |    value_loss           | 0.587        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 98.1         |
# | time/                   |              |
# |    fps                  | 1116         |
# |    iterations           | 24           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0026326627 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0941       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.977        |
# |    value_loss           | 0.396        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 98.2        |
# | time/                   |             |
# |    fps                  | 1112        |
# |    iterations           | 25          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004142968 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00135    |
# |    std                  | 0.972       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 98.4         |
# | time/                   |              |
# |    fps                  | 1113         |
# |    iterations           | 26           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0058143595 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0907       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.086        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.957        |
# |    value_loss           | 0.23         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 98.6        |
# | time/                   |             |
# |    fps                  | 1115        |
# |    iterations           | 27          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007476041 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0493      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0031     |
# |    std                  | 0.975       |
# |    value_loss           | 0.139       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 98.9         |
# | time/                   |              |
# |    fps                  | 1114         |
# |    iterations           | 28           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0035484047 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0111       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0524       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00321     |
# |    std                  | 0.977        |
# |    value_loss           | 0.102        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.1         |
# | time/                   |              |
# |    fps                  | 1115         |
# |    iterations           | 29           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0067148358 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.0131      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0338       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 0.958        |
# |    value_loss           | 0.0715       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.4        |
# | time/                   |             |
# |    fps                  | 1115        |
# |    iterations           | 30          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007340208 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00853     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.000294    |
# |    std                  | 0.955       |
# |    value_loss           | 0.0518      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.5         |
# | time/                   |              |
# |    fps                  | 1114         |
# |    iterations           | 31           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0026148781 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0323      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00873      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000214    |
# |    std                  | 0.944        |
# |    value_loss           | 0.0489       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.6         |
# | time/                   |              |
# |    fps                  | 1113         |
# |    iterations           | 32           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0034443925 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0309       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00249      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00198     |
# |    std                  | 0.939        |
# |    value_loss           | 0.0459       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.7         |
# | time/                   |              |
# |    fps                  | 1112         |
# |    iterations           | 33           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0037418017 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00852      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0135      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.000767     |
# |    std                  | 0.941        |
# |    value_loss           | 0.0356       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.7         |
# | time/                   |              |
# |    fps                  | 1111         |
# |    iterations           | 34           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0054269745 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0473      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0186       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000344     |
# |    std                  | 0.92         |
# |    value_loss           | 0.0143       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.7        |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 35          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008169277 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0173     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0503      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00116    |
# |    std                  | 0.914       |
# |    value_loss           | 0.0411      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.8         |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 36           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0047319136 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0064      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00403     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00251      |
# |    std                  | 0.912        |
# |    value_loss           | 0.00823      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.8         |
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 37           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0042729094 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.029        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00705     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -7.98e-05    |
# |    std                  | 0.925        |
# |    value_loss           | 0.00828      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.8         |
# | time/                   |              |
# |    fps                  | 1108         |
# |    iterations           | 38           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0062051658 |
# |    clip_fraction        | 0.0979       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00341     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0523       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00379     |
# |    std                  | 0.924        |
# |    value_loss           | 0.0807       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.8         |
# | time/                   |              |
# |    fps                  | 1101         |
# |    iterations           | 39           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0027824482 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00312     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0804       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.00146      |
# |    std                  | 0.94         |
# |    value_loss           | 0.0662       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.8         |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 40           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0049270494 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00116      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00343     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.000471     |
# |    std                  | 0.949        |
# |    value_loss           | 0.0221       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.8         |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 41           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0031158978 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0174       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00491      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.000199     |
# |    std                  | 0.944        |
# |    value_loss           | 0.00343      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.9         |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 42           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0041696085 |
# |    clip_fraction        | 0.056        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.101       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00536      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000625     |
# |    std                  | 0.942        |
# |    value_loss           | 0.00121      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.9         |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 43           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0026287134 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.024        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00515      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000628     |
# |    std                  | 0.951        |
# |    value_loss           | 0.00273      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 44          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005611069 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0285      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00928    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00174    |
# |    std                  | 0.95        |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 45           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018292636 |
# |    clip_fraction        | 0.0568       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.239       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.023        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000855     |
# |    std                  | 0.955        |
# |    value_loss           | 0.000576     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 100        |
# | time/                   |            |
# |    fps                  | 1103       |
# |    iterations           | 46         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00236982 |
# |    clip_fraction        | 0.0397     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.232     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00647   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.00116    |
# |    std                  | 0.95       |
# |    value_loss           | 0.000404   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 99.9       |
# | time/                   |            |
# |    fps                  | 1102       |
# |    iterations           | 47         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00802279 |
# |    clip_fraction        | 0.0689     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.217     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00691    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00061   |
# |    std                  | 0.958      |
# |    value_loss           | 0.00034    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.9         |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 48           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0024906273 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -1.16e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00106      |
# |    std                  | 0.971        |
# |    value_loss           | 0.0604       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1103        |
# |    iterations           | 49          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007973575 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.00258    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00688     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00112     |
# |    std                  | 0.986       |
# |    value_loss           | 0.0167      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 99.9         |
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 50           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0033292207 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.196       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0037      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000857     |
# |    std                  | 0.983        |
# |    value_loss           | 0.000183     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 51          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005880868 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.214      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000809    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.000495   |
# |    std                  | 0.971       |
# |    value_loss           | 0.000155    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# ...
# |    value_loss           | 3.39e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 58           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0053445273 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.981       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00317     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | 0.000215     |
# |    std                  | 0.973        |
# |    value_loss           | 2.25e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 59           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0028047527 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0019       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.000307     |
# |    std                  | 0.997        |
# |    value_loss           | 0.019        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1103        |
# |    iterations           | 60          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.001045093 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -1.36       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.000261    |
# |    std                  | 1           |
# |    value_loss           | 2.52e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1103        |
# |    iterations           | 61          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.002704008 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -6.77e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00504     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.000212   |
# |    std                  | 1.01        |
# |    value_loss           | 0.0781      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 62          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.015347942 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.000904   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00598    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.000637    |
# |    std                  | 1.03        |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 63          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.004780842 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0202      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00822    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.000804    |
# |    std                  | 1.03        |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 99.9       |
# | time/                   |            |
# |    fps                  | 1104       |
# |    iterations           | 64         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.00288771 |
# |    clip_fraction        | 0.0415     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | -2.29      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00941    |
# |    n_updates            | 630        |
# |    policy_gradient_loss | 0.00127    |
# |    std                  | 1.01       |
# |    value_loss           | 1.2e-05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 65          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.005517719 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -2.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0497      |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.0014      |
# |    std                  | 0.992       |
# |    value_loss           | 8.58e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 66          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.007872734 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -2.82       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00363    |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.000404    |
# |    std                  | 0.976       |
# |    value_loss           | 6.65e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1104         |
# |    iterations           | 67           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 137216       |
# | train/                  |              |
# |    approx_kl            | 0.0032742596 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -3.06        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00044     |
# |    std                  | 0.944        |
# |    value_loss           | 5.18e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1104         |
# |    iterations           | 68           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0054507134 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -3.39        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0236       |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00349     |
# |    std                  | 0.914        |
# |    value_loss           | 4.31e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 69          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.003557526 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -3.89       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00807     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.000241    |
# |    std                  | 0.908       |
# |    value_loss           | 3.52e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1104         |
# |    iterations           | 70           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0041147545 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -4.61        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000504    |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00137     |
# |    std                  | 0.896        |
# |    value_loss           | 3.08e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 71           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 145408       |
# | train/                  |              |
# |    approx_kl            | 0.0039419876 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -5.63        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00165      |
# |    n_updates            | 700          |
# |    policy_gradient_loss | 0.00106      |
# |    std                  | 0.892        |
# |    value_loss           | 2.53e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 1103        |
# |    iterations           | 72          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.010359537 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.000333   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.00363     |
# |    std                  | 0.904       |
# |    value_loss           | 0.0169      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 73           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0024859973 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.638       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00487      |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.000697    |
# |    std                  | 0.891        |
# |    value_loss           | 1.96e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 74           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0061715203 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.000282    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00976     |
# |    n_updates            | 730          |
# |    policy_gradient_loss | 0.00156      |
# |    std                  | 0.922        |
# |    value_loss           | 0.0169       |
# ------------------------------------------
# Training finished!

# %%
import os

ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Stochastic_model')
model.save(ppo_path)
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
import matplotlib.pyplot as plt
import numpy as np


obs, info = env.reset() 
concentrations = [obs[0]] # Store the history of concentrations


print("--- Running simulation with the trained agent ---")
for _ in range(env.max_steps):
    
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    concentrations.append(obs[0])
    
    if terminated or truncated:
        break

plt.figure(figsize=(12, 6))
plt.plot(concentrations, label='Drug Concentration', color='purple', linewidth=2)
plt.axhline(y=env.target_min, color='green', linestyle='--', label='Target Min')
plt.axhline(y=env.target_max, color='red', linestyle='--', label='Target Max')
plt.title("Learned Policy from Stable-Baselines3 Agent")
plt.xlabel("Time Step (Hour)")
plt.ylabel("Drug Concentration")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- Running simulation with the trained agent ---

# %%
import pickle
import numpy as np
from tqdm import tqdm

env = PatientEnvGymStochastic()
mixed_dataset = []
num_random_steps = 25000
num_expert_steps = 25000

# Collect RANDOM Data
print(f"Collecting {num_random_steps} steps of random data...")
obs, info = env.reset()
for _ in tqdm(range(num_random_steps)):
    action = env.action_space.sample()
    next_obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    mixed_dataset.append((obs, action, reward, next_obs, done))
    obs = next_obs if not done else env.reset()[0]

# Collect EXPERT Data
print(f"\nCollecting {num_expert_steps} steps of expert data...")
obs, info = env.reset()
for _ in tqdm(range(num_expert_steps)):
    action, _ = model.predict(obs, deterministic=True)
    next_obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    mixed_dataset.append((obs, action, reward, next_obs, done))
    obs = next_obs if not done else env.reset()[0]

# Save the new, correct dataset
with open('ppo_collected_dataset2.pkl', 'wb') as f:
    pickle.dump(mixed_dataset, f)

print("\n--- Mixed-quality data collection complete! ---")
print(f"Total experiences collected: {len(mixed_dataset)}")
print("Dataset saved to 'ppo_collected_dataset2.pkl'")
# Out:
# Stochastic Patient Environment created!
# Collecting 25000 steps of random data...
# 100%|█████████████████████████████████████████████████████████████████████████| 25000/25000 [00:01<00:00, 21180.88it/s]
# Collecting 25000 steps of expert data...
# 100%|██████████████████████████████████████████████████████████████████████████| 25000/25000 [00:06<00:00, 3758.29it/s]
# --- Mixed-quality data collection complete! ---
# Total experiences collected: 50000
# Dataset saved to 'ppo_collected_dataset2.pkl'

# %%
import pickle
import numpy as np
from d3rlpy.dataset import MDPDataset


with open('ppo_collected_dataset2.pkl', 'rb') as f:
    dataset = pickle.load(f)

print(f"Successfully loaded {len(dataset)} experiences.")


# d3rlpy expects data in this format
observations = np.array([experience[0] for experience in dataset])
actions = np.array([experience[1] for experience in dataset])
rewards = np.array([experience[2] for experience in dataset])
terminals = np.array([experience[4] for experience in dataset]) # 'done' flags

# --- 3. Create a d3rlpy-compatible dataset object ---
mdp_dataset = MDPDataset(
    observations=observations,
    actions=actions,
    rewards=rewards,
    terminals=terminals
)

print("Dataset is formatted and ready for d3rlpy!")
# Out:
# Successfully loaded 50000 experiences.
# 2025-10-25 15:39.21 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('float32')], shape=[(1,)]) observation_signature=Signature(dtype=[dtype('float32')], shape=[(1,)]) reward_signature=Signature(dtype=[dtype('int64')], shape=[(1,)])
# 2025-10-25 15:39.21 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.CONTINUOUS: 1>
# 2025-10-25 15:39.21 [info     ] Action size has been automatically determined. action_size=1
# Dataset is formatted and ready for d3rlpy!

# %%
from d3rlpy.algos import CQLConfig
import d3rlpy

# 1. Create the CQL agent 
cql = d3rlpy.algos.CQLConfig(
    conservative_weight=0.01,  # Makes the agent less cautious
    compile_graph=True
).create(device='cpu')

# 2. Start the offline training 
print("Starting offline training with CQL... This may take several minutes.")
cql.fit(
    mdp_dataset,
    n_steps=100  # Let's have the agent study the data 100 times.
)

print("\nOffline training complete!")
# Out:
# Starting offline training with CQL... This may take several minutes.
# 2025-10-25 15:39.30 [info     ] dataset info                   dataset_info=DatasetInfo(observation_signature=Signature(dtype=[dtype('float32')], shape=[(1,)]), action_signature=Signature(dtype=[dtype('float32')], shape=[(1,)]), reward_signature=Signature(dtype=[dtype('int64')], shape=[(1,)]), action_space=<ActionSpace.CONTINUOUS: 1>, action_size=1)
# 2025-10-25 15:39.30 [debug    ] Building models...
# 2025-10-25 15:39.30 [debug    ] Models have been built.
# 2025-10-25 15:39.30 [info     ] Directory is created at d3rlpy_logs\CQL_20251025153930
# 2025-10-25 15:39.30 [info     ] Parameters                     params={'observation_shape': [1], 'action_size': 1, 'config': {'type': 'cql', 'params': {'batch_size': 256, 'gamma': 0.99, 'observation_scaler': {'type': 'none', 'params': {}}, 'action_scaler': {'type': 'none', 'params': {}}, 'reward_scaler': {'type': 'none', 'params': {}}, 'compile_graph': True, 'actor_learning_rate': 0.0001, 'critic_learning_rate': 0.0003, 'temp_learning_rate': 0.0001, 'alpha_learning_rate': 0.0001, 'actor_optim_factory': {'type': 'adam', 'params': {'clip_grad_norm': None, 'lr_scheduler_factory': {'type': 'none', 'params': {}}, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}}, 'critic_optim_factory': {'type': 'adam', 'params': {'clip_grad_norm': None, 'lr_scheduler_factory': {'type': 'none', 'params': {}}, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}}, 'temp_optim_factory': {'type': 'adam', 'params': {'clip_grad_norm': None, 'lr_scheduler_factory': {'type': 'none', 'params': {}}, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}}, 'alpha_optim_factory': {'type': 'adam', 'params': {'clip_grad_norm': None, 'lr_scheduler_factory': {'type': 'none', 'params': {}}, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}}, 'actor_encoder_factory': {'type': 'default', 'params': {'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None}}, 'critic_encoder_factory': {'type': 'default', 'params': {'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None}}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'tau': 0.005, 'n_critics': 2, 'initial_temperature': 1.0, 'initial_alpha': 1.0, 'alpha_threshold': 10.0, 'conservative_weight': 0.01, 'n_action_samples': 10, 'soft_q_backup': False, 'max_q_backup': False}}}
#
# Offline training complete!

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Initialization ---
# Ensure you have your stochastic environment created in the 'env' variable
# and your trained offline agent in the 'cql' variable.
env = PatientEnvGymStochastic()
obs, info = env.reset() 

concentrations = [obs[0]] # Store the history of concentrations for plotting

# --- 2. Run one full episode with the OFFLINE-trained agent ---
print("--- Running simulation with the offline-trained CQL agent ---")
max_steps = 100 
for _ in range(max_steps):
    
    # a. Get the best action from the CQL agent's brain 🧠
    # d3rlpy's predict method expects a batch, so we add a dimension to our obs
    action= cql.predict(np.expand_dims(obs, axis=0))
    
    # b. Take that action in the environment
    obs, reward, terminated, truncated, info = env.step(action)
    
    # c. Store the result for plotting
    concentrations.append(obs[0])
    
    # d. If the episode ends, stop the loop
    if terminated or truncated:
        break

# --- 3. Plot the results ---
plt.figure(figsize=(12, 6))
plt.plot(concentrations, label='Drug Concentration', color='orange', linewidth=2)
plt.axhline(y=env.target_min, color='green', linestyle='--', label='Target Min')
plt.axhline(y=env.target_max, color='red', linestyle='--', label='Target Max')
plt.title("Learned Policy from Offline (CQL) Agent")
plt.xlabel("Time Step (Hour)")
plt.ylabel("Drug Concentration")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Stochastic Patient Environment created!
# --- Running simulation with the offline-trained CQL agent ---

# %%
import numpy as np
from tqdm import tqdm # A library for progress bars

# --- 1. Initialization ---
num_episodes = 100
env = PatientEnvGymStochastic()

# Lists to store the results from each episode
all_total_rewards = []
all_times_in_window = []
all_toxic_events = []

print(f"--- Starting evaluation of CQL agent for {num_episodes} episodes ---")

# --- 2. Evaluation Loop ---
for _ in tqdm(range(num_episodes)):
    obs, info = env.reset()
    
    # Metrics for this single episode
    episode_reward = 0
    steps_in_window = 0
    toxic_events = 0
    
    # Run one full episode
    for step in range(env.max_steps):
        # Predict and execute action
        action_array = cql.predict(np.expand_dims(obs, axis=0))
        obs, reward, terminated, truncated, info = env.step(action_array)
        
        # Update metrics
        episode_reward += reward
        if env.target_min <= env.current_concentration <= env.target_max:
            steps_in_window += 1
        if env.current_concentration > env.target_max:
            toxic_events += 1
        
        if terminated or truncated:
            break
            
    # After the episode, calculate and store the final metrics
    percent_in_window = (steps_in_window / env.max_steps) * 100
    all_total_rewards.append(episode_reward)
    all_times_in_window.append(percent_in_window)
    all_toxic_events.append(toxic_events)

# --- 3. Calculate and Print Final Statistics ---
mean_reward = np.mean(all_total_rewards)
std_reward = np.std(all_total_rewards)

mean_time_in_window = np.mean(all_times_in_window)
std_time_in_window = np.std(all_times_in_window)

mean_toxic_events = np.mean(all_toxic_events)
std_toxic_events = np.std(all_toxic_events)

print("\n--- CQL Agent Evaluation Results ---")
print(f"Average Total Reward:     {mean_reward:.2f} ± {std_reward:.2f}")
print(f"Time in Therapeutic Window: {mean_time_in_window:.2f}% ± {std_time_in_window:.2f}%")
print(f"Average Toxic Events:     {mean_toxic_events:.2f} ± {std_toxic_events:.2f}")
# Out:
# Stochastic Patient Environment created!
# --- Starting evaluation of CQL agent for 100 episodes ---
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.36it/s]
# --- CQL Agent Evaluation Results ---
# Average Total Reward:     45.30 ± 2.10
# Time in Therapeutic Window: 72.65% ± 1.05%
# Average Toxic Events:     0.00 ± 0.00

# %%
import numpy as np
from tqdm import tqdm

# --- 1. Initialization ---
num_episodes = 100
# Ensure you are using the final environment with the shaped reward
env = PatientEnvGymStochastic()
model = PPO.load(ppo_path, env)

# Lists to store the results
all_total_rewards = []
all_times_in_window = []
all_toxic_events = []

print(f"--- Starting evaluation of EXPERT PPO agent for {num_episodes} episodes ---")

# --- 2. Evaluation Loop ---
for _ in tqdm(range(num_episodes)):
    obs, info = env.reset()
    episode_reward = 0
    steps_in_window = 0
    toxic_events = 0
    
    for step in range(env.max_steps):
        # Use the PPO model to predict the action
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        
        # Update metrics
        episode_reward += reward
        if env.target_min <= env.current_concentration <= env.target_max:
            steps_in_window += 1
        if env.current_concentration > env.target_max:
            toxic_events += 1
        
        if terminated or truncated:
            break
            
    percent_in_window = (steps_in_window / env.max_steps) * 100
    all_total_rewards.append(episode_reward)
    all_times_in_window.append(percent_in_window)
    all_toxic_events.append(toxic_events)

# --- 3. Calculate and Print Final Statistics ---
mean_reward = np.mean(all_total_rewards)
std_reward = np.std(all_total_rewards)
mean_time_in_window = np.mean(all_times_in_window)
std_time_in_window = np.std(all_times_in_window)
mean_toxic_events = np.mean(all_toxic_events)
std_toxic_events = np.std(all_toxic_events)

print("\n--- EXPERT PPO Agent Evaluation Results ---")
print(f"Average Total Reward:     {mean_reward:.2f} ± {std_reward:.2f}")
print(f"Time in Therapeutic Window: {mean_time_in_window:.2f}% ± {std_time_in_window:.2f}%")
print(f"Average Toxic Events:     {mean_toxic_events:.2f} ± {std_toxic_events:.2f}")
# Out:
# Stochastic Patient Environment created!
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# --- Starting evaluation of EXPERT PPO agent for 100 episodes ---
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 36.78it/s]
# --- EXPERT PPO Agent Evaluation Results ---
# Average Total Reward:     100.00 ± 0.00
# Time in Therapeutic Window: 100.00% ± 0.00%
# Average Toxic Events:     0.00 ± 0.00

# %%
import numpy as np
from tqdm import tqdm

# --- 1. Initialization ---
num_episodes = 100
# Use the same shaped reward environment for a fair comparison
env = PatientEnvGymStochastic()

# Lists to store the results
all_total_rewards = []
all_times_in_window = []
all_toxic_events = []

print(f"--- Starting evaluation of NAIVE FIXED policy for {num_episodes} episodes ---")

# --- 2. Evaluation Loop ---
for _ in tqdm(range(num_episodes)):
    obs, info = env.reset()
    episode_reward = 0
    steps_in_window = 0
    toxic_events = 0
    
    for step in range(env.max_steps):
        # === THE NAIVE POLICY LOGIC ===
        action = 0.0 # Default action is 0mg
        if step > 0 and step % 10 == 0:
            action = 15.0 # Give 15mg dose every 10 hours
        # =============================

        obs, reward, terminated, truncated, info = env.step(action)
        
        # Update metrics
        episode_reward += reward
        if env.target_min <= env.current_concentration <= env.target_max:
            steps_in_window += 1
        if env.current_concentration > env.target_max:
            toxic_events += 1
        
        if terminated or truncated:
            break
            
    percent_in_window = (steps_in_window / env.max_steps) * 100
    all_total_rewards.append(episode_reward)
    all_times_in_window.append(percent_in_window)
    all_toxic_events.append(toxic_events)

# --- 3. Calculate and Print Final Statistics ---
mean_reward = np.mean(all_total_rewards)
std_reward = np.std(all_total_rewards)
mean_time_in_window = np.mean(all_times_in_window)
std_time_in_window = np.std(all_times_in_window)
mean_toxic_events = np.mean(all_toxic_events)
std_toxic_events = np.std(all_toxic_events)

print("\n--- NAIVE FIXED Policy Evaluation Results ---")
print(f"Average Total Reward:     {mean_reward:.2f} ± {std_reward:.2f}")
print(f"Time in Therapeutic Window: {mean_time_in_window:.2f}% ± {std_time_in_window:.2f}%")
print(f"Average Toxic Events:     {mean_toxic_events:.2f} ± {std_toxic_events:.2f}")
# Out:
# Stochastic Patient Environment created!
# --- Starting evaluation of NAIVE FIXED policy for 100 episodes ---
# 100%|██████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 2665.54it/s]
# --- NAIVE FIXED Policy Evaluation Results ---
# Average Total Reward:     10.88 ± 3.91
# Time in Therapeutic Window: 55.44% ± 1.96%
# Average Toxic Events:     34.54 ± 1.96

# %%
import pickle
import numpy as np


with open('ppo_collected_dataset2.pkl', 'rb') as f:
    freshly_loaded_dataset = pickle.load(f)

print(f"Loaded data type: {type(freshly_loaded_dataset)}")
print(f"Total experiences in loaded file: {len(freshly_loaded_dataset)}")


num_random_steps = 25000
expert_data = freshly_loaded_dataset[num_random_steps:]

print(f"Extracted {len(expert_data)} expert experiences for Behavior Cloning.")


# X is the input (the state/observation)
# y is the output we want to imitate (the expert's action)
X_train = np.array([experience[0] for experience in expert_data])
y_train = np.array([experience[1] for experience in expert_data])

print("Data is ready for training the BC model.")
# Out:
# Loaded data type: <class 'list'>
# Total experiences in loaded file: 50000
# Extracted 25000 expert experiences for Behavior Cloning.
# Data is ready for training the BC model.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# --- 1. Build the model architecture ---
# This can be a simple multi-layer perceptron (MLP)
bc_model = Sequential([
    Dense(64, input_dim=X_train.shape[1], activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='linear') # Output one continuous value (the dosage)
])

# --- 2. Compile the model ---
# We use Mean Squared Error because this is a regression problem.
bc_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

print("--- Training the Behavior Cloning Model ---")
# --- 3. Train the model ---
bc_model.fit(
    X_train,
    y_train,
    validation_split=0.2, # Use 20% of data for validation
    epochs=50,            # Train for 50 passes over the data
    batch_size=256,
    verbose=1             # Show training progress
)
print("\n--- Behavior Cloning Model Training Complete! ---")
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# --- Training the Behavior Cloning Model ---
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6190 - val_loss: 0.5645
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5120 - val_loss: 0.4444
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3547 - val_loss: 0.2479
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1529 - val_loss: 0.0664
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0268 - val_loss: 0.0046
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - val_loss: 2.2960e-04
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1157e-04 - val_loss: 8.6464e-05
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2249e-04 - val_loss: 8.2147e-05
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1315e-04 - val_loss: 8.9856e-05
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3024e-04 - val_loss: 1.0419e-04
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3487e-04 - val_loss: 9.6031e-05
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6729e-04 - val_loss: 1.3831e-04
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1495e-04 - val_loss: 1.6232e-04
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1546e-04 - val_loss: 1.9566e-04
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2835e-04 - val_loss: 4.2337e-04
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1997e-04 - val_loss: 0.0025
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1340e-04 - val_loss: 3.8803e-04
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1705e-04 - val_loss: 1.0601e-04
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6568e-04 - val_loss: 4.9081e-05
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2783e-04 - val_loss: 2.5834e-04
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7501e-04 - val_loss: 0.0015
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9619e-04 - val_loss: 1.0026e-04
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6207e-04 - val_loss: 5.6670e-04
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8876e-04 - val_loss: 6.4065e-04
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3878e-04 - val_loss: 1.7356e-04
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6269e-04 - val_loss: 7.1399e-04
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9511e-04 - val_loss: 5.3824e-05
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6382e-04 - val_loss: 2.3893e-04
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8950e-04 - val_loss: 1.9361e-04
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6025e-04 - val_loss: 2.8705e-04
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0476e-04 - val_loss: 5.0188e-04
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7509e-04 - val_loss: 3.9075e-05
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2776e-04 - val_loss: 0.0023
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9528e-04 - val_loss: 9.2186e-05
# Epoch 35/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9847e-04 - val_loss: 4.0079e-04
# Epoch 36/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7405e-04 - val_loss: 1.0318e-04
# Epoch 37/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6904e-04 - val_loss: 2.4644e-05
# Epoch 38/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6647e-04 - val_loss: 2.4093e-04
# Epoch 39/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1937e-04 - val_loss: 7.6907e-04
# Epoch 40/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9964e-04 - val_loss: 1.7622e-04
# Epoch 41/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7108e-04 - val_loss: 0.0077
# Epoch 42/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 43/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5099e-04 - val_loss: 1.3471e-05
# Epoch 44/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2381e-05 - val_loss: 1.3356e-05
# Epoch 45/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5820e-05 - val_loss: 2.8987e-05
# Epoch 46/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5930e-05 - val_loss: 1.4324e-05
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5218e-04 - val_loss: 2.6323e-04
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 4.7361e-04
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 2.1304e-05
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7544e-05 - val_loss: 1.9096e-05
#
# --- Behavior Cloning Model Training Complete! ---

# %%
import numpy as np
from tqdm import tqdm

# --- 1. Initialization ---
num_episodes = 100
env = PatientEnvGymStochastic()

# Lists to store the results
all_total_rewards = []
all_times_in_window = []
all_toxic_events = []

print(f"--- Starting evaluation of BEHAVIOR CLONING agent for {num_episodes} episodes ---")

# --- 2. Evaluation Loop ---
for _ in tqdm(range(num_episodes)):
    obs, info = env.reset()
    episode_reward = 0
    steps_in_window = 0
    toxic_events = 0
    
    for step in range(env.max_steps):
        # Use the BC model to predict the action
        # We reshape the observation to have a batch dimension for the model
        action = bc_model.predict(obs.reshape(1, -1), verbose=0)
        obs, reward, terminated, truncated, info = env.step(action)
        
        # Update metrics
        episode_reward += reward
        if env.target_min <= env.current_concentration <= env.target_max:
            steps_in_window += 1
        if env.current_concentration > env.target_max:
            toxic_events += 1
        
        if terminated or truncated:
            break
            
    percent_in_window = (steps_in_window / env.max_steps) * 100
    all_total_rewards.append(episode_reward)
    all_times_in_window.append(percent_in_window)
    all_toxic_events.append(toxic_events)

# --- 3. Calculate and Print Final Statistics ---
mean_reward = np.mean(all_total_rewards)
std_reward = np.std(all_total_rewards)
mean_time_in_window = np.mean(all_times_in_window)
std_time_in_window = np.std(all_times_in_window)
mean_toxic_events = np.mean(all_toxic_events)
std_toxic_events = np.std(all_toxic_events)

print("\n--- BEHAVIOR CLONING Agent Evaluation Results ---")
print(f"Average Total Reward:     {mean_reward:.2f} ± {std_reward:.2f}")
print(f"Time in Therapeutic Window: {mean_time_in_window:.2f}% ± {std_time_in_window:.2f}%")
print(f"Average Toxic Events:     {mean_toxic_events:.2f} ± {std_toxic_events:.2f}")
# Out:
# Stochastic Patient Environment created!
# --- Starting evaluation of BEHAVIOR CLONING agent for 100 episodes ---
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [09:04<00:00,  5.45s/it]
# --- BEHAVIOR CLONING Agent Evaluation Results ---
# Average Total Reward:     100.00 ± 0.00
# Time in Therapeutic Window: 100.00% ± 0.00%
# Average Toxic Events:     0.00 ± 0.00

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Initialization ---
# Ensure you are using your final, robust environment class
env = PatientEnvGymStochastic() 
obs, info = env.reset() 

# List to store the history of concentrations for plotting
concentrations = [obs[0]] 

print("--- Running simulation with the Behavior Cloning agent ---")

# --- 2. Run one full episode ---
for _ in range(env.max_steps):
    
    # a. Get the best action from the Behavior Cloning model 🧠
    # We reshape the observation to have a batch dimension (e.g., [[value]]) for the model.
    action = bc_model.predict(obs.reshape(1, -1), verbose=0)
    
    # b. Take that action in the environment
    obs, reward, terminated, truncated, info = env.step(action)
    
    # c. Store the result for plotting
    concentrations.append(obs[0])
    
    # d. If the episode ends, stop the loop
    if terminated or truncated:
        break

# --- 3. Plot the results ---
plt.figure(figsize=(12, 6))
plt.plot(concentrations, label='Drug Concentration', color='blue', linewidth=2)
plt.axhline(y=env.target_min, color='green', linestyle='--', label='Target Min')
plt.axhline(y=env.target_max, color='red', linestyle='--', label='Target Max')
plt.title("Learned Policy from Behavior Cloning Agent")
plt.xlabel("Time Step (Hour)")
plt.ylabel("Drug Concentration")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Stochastic Patient Environment created!
# --- Running simulation with the Behavior Cloning agent ---
